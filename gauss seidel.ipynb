# %%
# Defining our function as seidel which takes 3 arguments
# as A matrix, Solution and B matrix
   
def seidel(a, x ,b):
    #Finding length of a      
    n = len(a)              
    # for loop for n times as to calculate x, y , z
    for j in range(n):        
        # temp variable d to store b[j]
        d = b[j]                  
          
        # to calculate respective xi, yi, zi
        for i in range(n):     
            if(j != i):
                d-=a[j][i] * x[i]
        # updating the value of our solution        
        x[j] = d / a[j][j]
    # returning our updated solution           
    return x    
   
# int(input())input as number of variable to be solved                
#n = int(input("Donner nombre des variables"))  
a = []                            
b = []
x = []   
epsilon = float(input("Donner l'epsilon"))
test=True
"""for i in range(n):
    l=[]
    for j in range(n):
        l.append(int(input("Donner A{}{}".format(i,j))))
    a.append(l)                            
for i in range(n):
    b.append(int(input("Donner b{}".format(i))))
    #b[i]=int(input("Donner b{}".format(i)))
    x.append(0)
print(x)"""
# initial solution depending on n(here n=3)                     
import copy
#dummy data
n=3
x = [0.0, 0.0, 0.0]                         
a = [[5, -2, 3],[-3, 9, 1],[2, -1, -7]]
b = [-1,2,3]
x1 = [0.0, 0.0, 0.0]
#loop run for m times depending on m the error value
while test:         
    x = seidel(a, x, b)
    #print each time the updated solution
    print("x",x)
    i=0
    while(test and i<n):
        if(abs(x1[i]-x[i])<=epsilon):
            test=False
            break
        i=i+1
    x1=copy.copy(x)
# Out:
# x [-0.2, 0.15555555555555556, -0.5079365079365079]
# x [0.16698412698412696, 0.33432098765432094, -0.42862181909800956]
# x [0.19090148652053412, 0.3334806976288458, -0.4216682463696825]
# x [0.18639322687334783, 0.33120532522108065, -0.4226312673534835]
# x [0.18606089050052235, 0.3312015487616723, -0.4227256811086611]
